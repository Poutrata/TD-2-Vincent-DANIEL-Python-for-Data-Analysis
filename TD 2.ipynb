# %% [markdown]
# Import it into pandas, into a Jupyter Notebook.¶
# Find and answer 3 questions to ask using pandas, including aggregates.
# Find and display 3 plots using matplotlib, including pivot tables.
# Publish your notebook on GitHub or Collab
# I will ask some of you to show it and talk about it in the classroom.

# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame
import matplotlib.pyplot as plt

# %%
country = pd.read_csv("Country.csv",sep=",")

# %%
country
# Out:
#     CountryCode                 ShortName                 TableName  \
# 0           AFG               Afghanistan               Afghanistan
# 1           ALB                   Albania                   Albania
# 2           DZA                   Algeria                   Algeria
# 3           ASM            American Samoa            American Samoa
# 4           ADO                   Andorra                   Andorra
# 5           AGO                    Angola                    Angola
# 6           ATG       Antigua and Barbuda       Antigua and Barbuda
# 7           ARB                Arab World                Arab World
# 8           ARG                 Argentina                 Argentina
# 9           ARM                   Armenia                   Armenia
# 10          ABW                     Aruba                     Aruba
# 11          AUS                 Australia                 Australia
# 12          AUT                   Austria                   Austria
# ...

# %% [markdown]
# What is the average year when industrial data was collected ?

# %%
country.LatestIndustrialData.agg("mean")
# Out:
# 2009.0796460176991

# %% [markdown]
# In what country do we have the oldest data and what year was it last refreshed?

# %%
country.groupby('LatestPopulationCensus').ShortName.sum()[:1]
# Out:
# LatestPopulationCensus
# 1943    Lebanon
# Name: ShortName, dtype: object

# %% [markdown]
# What country are counted as in South Asia ?

# %%
country[(country.Region=="South Asia")].groupby('ShortName').Region.sum()
# Out:
# ShortName
# Afghanistan    South Asia
# Bangladesh     South Asia
# Bhutan         South Asia
# India          South Asia
# Maldives       South Asia
# Nepal          South Asia
# Pakistan       South Asia
# Sri Lanka      South Asia
# Name: Region, dtype: object

# %% [markdown]
# Graph of date of aquisition of trade and water withrawl data

# %%
country.groupby('LatestIndustrialData').sum().plot()

# %%
country.groupby('LatestTradeData').sum().plot()

# %% [markdown]
# These graphs look really different, while they really shouldn't as they are depecting quite similar values, which is really weird.

# %%
table = pd.pivot_table(country, values='LatestWaterWithdrawalData', index=['ShortName'], columns=['Region'], aggfunc=np.sum)

# %%
table
# Out:
# Region                    East Asia & Pacific  Europe & Central Asia  \
# ShortName
# Afghanistan                               NaN                    NaN
# Albania                                   NaN                 2006.0
# Algeria                                   NaN                    NaN
# American Samoa                            0.0                    NaN
# Andorra                                   NaN                    0.0
# Angola                                    NaN                    NaN
# Antigua and Barbuda                       NaN                    NaN
# Argentina                                 NaN                    NaN
# Armenia                                   NaN                 2012.0
# Aruba                                     NaN                    NaN
# Australia                              2000.0                    NaN
# Austria                                   NaN                 2002.0
# ...
